# %% [markdown]
# <a href="https://colab.research.google.com/github/Disha-1102/first-repository/blob/main/Task1_Chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Chatbot: Hello! I am your rule-based chatbot ")
print("Chatbot: You can ask me about greetings, weather, time, name, AI, programming, jokes, etc.")
print("Chatbot: Type 'bye' to exit.\n")

while True:

    user_input = input("You: ").lower()
    if "bye" in user_input or "exit" in user_input:
        print("Chatbot: Goodbye!  Have a nice day!")
        break

    elif "hello" in user_input or "hi" in user_input or "hey" in user_input:
        print("Chatbot: Hi! How can I help you? ")

    elif "your name" in user_input:
        print("Chatbot: My name is RoboChat. I am created using Python! ")

    elif "how are you" in user_input:
        print("Chatbot: I am doing great! Thanks for asking ")

    elif "weather" in user_input:
        print("Chatbot: I can’t check real weather 🌦 but I guess it's nice outside!")

    elif "what is ai" in user_input or "artificial intelligence" in user_input:
        print("Chatbot: AI means making machines think and behave like humans ")

    elif "python" in user_input:
        print("Chatbot: Python is a popular programming language used in AI, Data Science, and Web Development!")

    elif "java" in user_input:
        print("Chatbot: Java is an object-oriented programming language widely used in software development!")

    elif "joke" in user_input:
        print("Chatbot: Why don't programmers like nature? Too many bugs! ")

    elif "time" in user_input:
        print("Chatbot: Time to learn Python! ")

    elif "help" in user_input:
        print("Chatbot: I can help you with greetings, programming basics, AI knowledge and fun chat! ")

    elif "who am i" in user_input:
        print("Chatbot: You are an amazing human using a chatbot! ")

    elif "love" in user_input:
        print("Chatbot: Love is a beautiful feeling! Spread positivity ")

    else:
        print("Chatbot: Sorry, I didn’t understand that. Can you say it another way?")
# Out:
# Chatbot: Hello! I am your rule-based chatbot
# Chatbot: You can ask me about greetings, weather, time, name, AI, programming, jokes, etc.
# Chatbot: Type 'bye' to exit.
#
# You: hello
# Chatbot: Hi! How can I help you?
# You: explain python
# Chatbot: Python is a popular programming language used in AI, Data Science, and Web Development!
# You: what is the time
# Chatbot: Time to learn Python!
# You: bye
# Chatbot: Goodbye!  Have a nice day!
